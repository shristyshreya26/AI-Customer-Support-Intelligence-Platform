# %%
import pandas as pd
import numpy as np
import joblib

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    balanced_accuracy_score,
    classification_report,
    ConfusionMatrixDisplay
)

from xgboost import XGBClassifier

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/processed/clean_customer_support_dataset_with_derived_sentiment.csv")

print(df.shape)

df.head()
# Out:
# (100000, 25)
#      ticket_id           created_at customer_id customer_segment  \
# 0  TCKT_000001  2024-01-31 05:14:27  CUST_00861       individual
# 1  TCKT_000002  2024-10-20 06:15:49  CUST_00770       individual
# 2  TCKT_000003  2024-06-18 21:35:54  CUST_02559   small_business
# 3  TCKT_000004  2025-12-25 15:59:52  CUST_03557        education
# 4  TCKT_000005  2023-08-27 16:08:33  CUST_09556       enterprise
#
#             channel         product_area        issue_type priority  \
# 0             email          data_export    account_access      low
# 1            in_app              billing  security_concern   medium
# 2              chat      api_integration               bug      low
# 3              chat  analytics_dashboard    account_access   medium
# 4  phone_transcript           login_auth   billing_problem      low
#
#              status  sla_plan  ... customer_sentiment csat_score  \
# 0          resolved  standard  ...      very_negative          1
# ...

# %%
columns = [

    "issue_type",

    "priority",

    "channel",

    "customer_segment",

    "platform",

    "region",

    "product_area",

    "customer_sentiment_derived",

    "has_attachment",

    "resolution_time_hours"

]

df = df[columns]

df = df.dropna()

df.head()
# Out:
#          issue_type priority           channel customer_segment    platform  \
# 0    account_access      low             email       individual     android
# 1  security_concern   medium            in_app       individual         web
# 4   billing_problem      low  phone_transcript       enterprise         web
# 5       performance      low             email        education         ios
# 6  security_concern   urgent            in_app        education  api_client
#
#     region product_area customer_sentiment_derived  has_attachment  \
# 0       EU  data_export                    neutral               0
# 1  Unknown      billing                    neutral               0
# 4  Unknown   login_auth                    neutral               0
# 5  Unknown   mobile_app                    neutral               0
# 6     APAC      billing                    neutral               1
#
#    resolution_time_hours
# 0                  36.53
# 1                 238.32
# 4                  61.32
# ...

# %%
def escalation_score(row):

    score = 0

    priority_scores = {
        "low": 1,
        "medium": 2,
        "high": 4,
        "urgent": 6
    }

    score += priority_scores.get(str(row["priority"]).lower(), 2)

    sentiment_scores = {
        "positive": 0,
        "neutral": 1,
        "negative": 3,
        "very_negative": 5
    }

    score += sentiment_scores.get(str(row["customer_sentiment_derived"]).lower(), 1)

    critical_products = ["security", "login_auth", "api_integration", "payments", "billing"]
    if any(p in str(row["product_area"]).lower() for p in critical_products):
        score += 2

    critical_issues = ["security_concern", "bug", "billing_problem"]
    if row["issue_type"] in critical_issues:
        score += 2

    if str(row["customer_segment"]).lower() == "enterprise":
        score += 2

    if row["has_attachment"] == 1:
        score += 1

    if row["resolution_time_hours"] > 72:
        score += 3
    elif row["resolution_time_hours"] > 24:
        score += 1

    return score

# %%
df["risk_score"] = df.apply(
    escalation_score,
    axis=1
)

# %%
def risk_label(score):

    if score <= 5:

        return "Low"

    elif score <= 10:

        return "Medium"

    else:

        return "High"

df["escalation_risk"] = df["risk_score"].apply(
    risk_label
)

# %%
print(df["escalation_risk"].value_counts())
# Out:
# escalation_risk
# Medium    32897
# Low       22692
# High       4524
# Name: count, dtype: int64

# %%
df = df.drop(
    columns=[
        "risk_score",
        "resolution_time_hours"
    ]
)

# %%
from sklearn.preprocessing import LabelEncoder

encoders = {}

categorical_columns = [

    "issue_type",

    "priority",

    "channel",

    "customer_segment",

    "platform",

    "region",

    "product_area",

    "customer_sentiment_derived",

    "has_attachment"

]

for col in categorical_columns:

    le = LabelEncoder()

    df[col] = le.fit_transform(df[col].astype(str))

    encoders[col] = le

# %%
target_encoder = LabelEncoder()

df["escalation_risk"] = target_encoder.fit_transform(
    df["escalation_risk"]
)

# %%
feature_columns = categorical_columns

X = df[feature_columns]

y = df["escalation_risk"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(

    X,

    y,

    test_size=0.20,

    random_state=42,

    stratify=y

)

print("Training Shape :", X_train.shape)
print("Testing Shape  :", X_test.shape)
# Out:
# Training Shape : (48090, 9)
# Testing Shape  : (12023, 9)

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

classes = np.unique(y_train)

weights = compute_class_weight(
    class_weight="balanced",
    classes=classes,
    y=y_train
)

class_weights = dict(zip(classes, weights))

print(class_weights)
# Out:
# {np.int64(0): np.float64(4.429400386847195), np.int64(1): np.float64(0.883000991517021), np.int64(2): np.float64(0.609111980848881)}

# %%
sample_weights = y_train.map(class_weights)

# %%
from xgboost import XGBClassifier

model = XGBClassifier(

    objective="multi:softprob",

    num_class=3,

    n_estimators=300,

    learning_rate=0.05,

    max_depth=5,

    min_child_weight=2,

    subsample=0.9,

    colsample_bytree=0.9,

    eval_metric="mlogloss",

    random_state=42,

    n_jobs=-1

)

model.fit(

    X_train,

    y_train,

    sample_weight=sample_weights

)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=2, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=-1, num_class=3, ...)

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)

print("Accuracy :", accuracy_score(y_test, predictions))

print("Balanced Accuracy :", balanced_accuracy_score(y_test, predictions))

print("Precision :", precision_score(
    y_test,
    predictions,
    average="weighted"
))

print("Recall :", recall_score(
    y_test,
    predictions,
    average="weighted"
))

print("F1 Score :", f1_score(
    y_test,
    predictions,
    average="weighted"
))
# Out:
# Accuracy : 0.8447974715129335
# Balanced Accuracy : 0.8392056093848742
# Precision : 0.8581774048013788
# Recall : 0.8447974715129335
# F1 Score : 0.8487370808342757

# %%
print(classification_report(

    y_test,

    predictions,

    target_names=target_encoder.classes_

))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.54      0.81      0.65       905
#          Low       0.88      0.88      0.88      4538
#       Medium       0.89      0.82      0.85      6580
#
#     accuracy                           0.84     12023
#    macro avg       0.77      0.84      0.79     12023
# weighted avg       0.86      0.84      0.85     12023

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ConfusionMatrixDisplay.from_predictions(

    y_test,

    predictions,

    display_labels=target_encoder.classes_

)

plt.show()

# %%
importance = pd.DataFrame({

    "Feature": feature_columns,

    "Importance": model.feature_importances_

})

importance = importance.sort_values(

    "Importance",

    ascending=False

)

print(importance)

plt.figure(figsize=(8,5))

plt.barh(

    importance["Feature"],

    importance["Importance"]

)

plt.gca().invert_yaxis()

plt.title("Feature Importance")

plt.show()
# Out:
#                       Feature  Importance
# 7  customer_sentiment_derived    0.327711
# 1                    priority    0.180116
# 0                  issue_type    0.136730
# 3            customer_segment    0.127132
# 6                product_area    0.105571
# 8              has_attachment    0.089484
# 4                    platform    0.011208
# 2                     channel    0.011138
# 5                      region    0.010909

# %%
import joblib

joblib.dump(
    model,
    "../models/escalation_model.pkl"
)

joblib.dump(
    encoders,
    "../models/escalation_encoders.pkl"
)

joblib.dump(
    target_encoder,
    "../models/escalation_target_encoder.pkl"
)
# Out:
# ['../models/escalation_target_encoder.pkl']

# %%
escalation_mapping = {
    "Low": {
        "color": "🟢",
        "description": "Routine issue. Standard support process is sufficient."
    },
    "Medium": {
        "color": "🟡",
        "description": "Requires closer monitoring. May need senior support involvement."
    },
    "High": {
        "color": "🔴",
        "description": "High priority. Immediate attention and possible escalation recommended."
    }
}

joblib.dump(
    escalation_mapping,
    "../models/escalation_mapping.pkl"
)
# Out:
# ['../models/escalation_mapping.pkl']
