# %%
import os
import pandas as pd

# Load unique issue dataset
issue_df = pd.read_csv("../data/processed/issue_classification.csv")

os.makedirs("../prompts", exist_ok=True)

labels = sorted(issue_df["label"].unique())

print(labels)
# Out:
# ['account_access', 'billing_problem', 'bug', 'feature_request', 'how_to', 'other', 'performance', 'security_concern']

# %%
for label in labels:

    examples = (
        issue_df[issue_df["label"] == label]["text"]
        .drop_duplicates()
        .tolist()
    )

    prompt = f"""
You are helping create a high-quality NLP dataset.

Issue Category:
{label}

Below are all the unique examples available in my dataset.

Study them carefully.

Understand the issue category.

DO NOT COPY THEM.

DO NOT PARAPHRASE THEM.

Generate exactly 50 NEW customer support tickets.

The new tickets must:

• belong to the SAME issue category

• describe DIFFERENT situations

• be realistic

• sound human

• include

- beginners
- enterprise users
- students
- developers
- elderly users
- frustrated users
- polite users

Mix

- short
- medium
- long

Return ONLY the tickets.

One ticket per line.

No numbering.

No markdown.

Examples:

"""

    for example in examples:

        prompt += f"- {example}\n"

    filename = f"../prompts/{label}.txt"

    with open(filename, "w", encoding="utf-8") as f:

        f.write(prompt)

print("Done!")
# Out:
# Done!

# %%
label = "account_access"

examples = (
    issue_df[issue_df["label"] == label]["text"]
    .drop_duplicates()
    .tolist()
)

print(f"Number of unique examples: {len(examples)}\n")

for i, example in enumerate(examples, 1):
    print(f"{i}. {example}\n")
# Out:
# Number of unique examples: 3
#
# 1. my account was locked after multiple failed login attempts.
#
# 2. i cannot log in; the system says my password is incorrect.
#
# 3. my 2fa code is not working when i try to sign in.

# %%
label = "billing_problem"

examples = (
    issue_df[issue_df["label"] == label]["text"]
    .drop_duplicates()
    .tolist()
)

print(f"Number of unique examples: {len(examples)}\n")

for i, example in enumerate(examples, 1):
    print(f"{i}. {example}\n")
# Out:
# Number of unique examples: 3
#
# 1. i downgraded my plan but i am still being billed for the higher tier.
#
# 2. i was charged twice for my subscription this month.
#
# 3. my invoice amount is incorrect compared to the plan i selected.

# %%
label = "bug"

examples = (
    issue_df[issue_df["label"] == label]["text"]
    .drop_duplicates()
    .tolist()
)

print(f"Number of unique examples: {len(examples)}\n")

for i, example in enumerate(examples, 1):
    print(f"{i}. {example}\n")
# Out:
# Number of unique examples: 21
#
# 1. i am seeing an error message when i click on data export.
#
# 2. the billing feature is not saving my changes.
#
# 3. the page keeps crashing whenever i try to open the api integration section.
#
# 4. the page keeps crashing whenever i try to open the notifications section.
#
# 5. the page keeps crashing whenever i try to open the billing section.
#
# 6. the page keeps crashing whenever i try to open the analytics dashboard section.
#
# 7. the notifications feature is not saving my changes.
#
# 8. the mobile app feature is not saving my changes.
#
# 9. the page keeps crashing whenever i try to open the login auth section.
#
# 10. i am seeing an error message when i click on billing.
#
# 11. i am seeing an error message when i click on api integration.
#
# 12. i am seeing an error message when i click on mobile app.
#
# 13. the data export feature is not saving my changes.
#
# 14. the page keeps crashing whenever i try to open the data export section.
#
# 15. the analytics dashboard feature is not saving my changes.
#
# 16. i am seeing an error message when i click on notifications.
#
# 17. the api integration feature is not saving my changes.
#
# 18. the login auth feature is not saving my changes.
#
# 19. i am seeing an error message when i click on analytics dashboard.
#
# 20. i am seeing an error message when i click on login auth.
#
# 21. the page keeps crashing whenever i try to open the mobile app section.

# %%
label = "feature_request"

examples = (
    issue_df[issue_df["label"] == label]["text"]
    .drop_duplicates()
    .tolist()
)

print(f"Number of unique examples: {len(examples)}\n")

for i, example in enumerate(examples, 1):
    print(f"{i}. {example}\n")
# Out:
# Number of unique examples: 21
#
# 1. can you add an option to customize data export?
#
# 2. our team needs more advanced options for billing.
#
# 3. it would be great to have mobile app support in your product.
#
# 4. it would be great to have billing support in your product.
#
# 5. it would be great to have api integration support in your product.
#
# 6. it would be great to have notifications support in your product.
#
# 7. it would be great to have data export support in your product.
#
# 8. our team needs more advanced options for data export.
#
# 9. it would be great to have login auth support in your product.
#
# 10. our team needs more advanced options for analytics dashboard.
#
# 11. our team needs more advanced options for notifications.
#
# 12. our team needs more advanced options for mobile app.
#
# 13. it would be great to have analytics dashboard support in your product.
#
# 14. can you add an option to customize billing?
#
# 15. can you add an option to customize notifications?
#
# 16. can you add an option to customize api integration?
#
# 17. our team needs more advanced options for login auth.
#
# 18. can you add an option to customize mobile app?
#
# 19. our team needs more advanced options for api integration.
#
# 20. can you add an option to customize analytics dashboard?
#
# 21. can you add an option to customize login auth?

# %%
label = "other"

examples = (
    issue_df[issue_df["label"] == label]["text"]
    .drop_duplicates()
    .tolist()
)

print(f"Number of unique examples: {len(examples)}\n")

for i, example in enumerate(examples, 1):
    print(f"{i}. {example}\n")
# Out:
# Number of unique examples: 3
#
# 1. i need help but i'm not sure which category this fits in.
#
# 2. something seems off, can you please check my workspace?
#
# 3. i have a general question about my account.

# %%
label = "how_to"

examples = (
    issue_df[issue_df["label"] == label]["text"]
    .drop_duplicates()
    .tolist()
)

print(f"Number of unique examples: {len(examples)}\n")

for i, example in enumerate(examples, 1):
    print(f"{i}. {example}\n")
# Out:
# Number of unique examples: 21
#
# 1. i need help setting up mobile app for my team.
#
# 2. can you explain how to configure data export properly?
#
# 3. can you explain how to configure notifications properly?
#
# 4. can you explain how to configure api integration properly?
#
# 5. can you explain how to configure billing properly?
#
# 6. i need help setting up billing for my team.
#
# 7. how can i export my data from the api integration section?
#
# 8. can you explain how to configure mobile app properly?
#
# 9. how can i export my data from the notifications section?
#
# 10. i need help setting up notifications for my team.
#
# 11. can you explain how to configure login auth properly?
#
# 12. i need help setting up analytics dashboard for my team.
#
# 13. how can i export my data from the login auth section?
#
# 14. i need help setting up login auth for my team.
#
# 15. how can i export my data from the mobile app section?
#
# 16. i need help setting up api integration for my team.
#
# 17. how can i export my data from the analytics dashboard section?
#
# 18. i need help setting up data export for my team.
#
# 19. how can i export my data from the billing section?
#
# 20. how can i export my data from the data export section?
#
# 21. can you explain how to configure analytics dashboard properly?

# %%
label = "performance"

examples = (
    issue_df[issue_df["label"] == label]["text"]
    .drop_duplicates()
    .tolist()
)

print(f"Number of unique examples: {len(examples)}\n")

for i, example in enumerate(examples, 1):
    print(f"{i}. {example}\n")
# Out:
# Number of unique examples: 15
#
# 1. overall performance has degraded in the last few days.
#
# 2. queries in the data export module are timing out.
#
# 3. queries in the billing module are timing out.
#
# 4. queries in the login auth module are timing out.
#
# 5. queries in the analytics dashboard module are timing out.
#
# 6. queries in the api integration module are timing out.
#
# 7. the login auth page is very slow and takes a long time to load.
#
# 8. the api integration page is very slow and takes a long time to load.
#
# 9. the notifications page is very slow and takes a long time to load.
#
# 10. queries in the mobile app module are timing out.
#
# 11. the analytics dashboard page is very slow and takes a long time to load.
#
# 12. the billing page is very slow and takes a long time to load.
#
# 13. the mobile app page is very slow and takes a long time to load.
#
# 14. queries in the notifications module are timing out.
#
# 15. the data export page is very slow and takes a long time to load.

# %%
label = "security_concern"

examples = (
    issue_df[issue_df["label"] == label]["text"]
    .drop_duplicates()
    .tolist()
)

print(f"Number of unique examples: {len(examples)}\n")

for i, example in enumerate(examples, 1):
    print(f"{i}. {example}\n")
# Out:
# Number of unique examples: 9
#
# 1. i noticed a suspicious login on my account.
#
# 2. there seems to be a vulnerability in the api integration functionality.
#
# 3. there seems to be a vulnerability in the login auth functionality.
#
# 4. there seems to be a vulnerability in the analytics dashboard functionality.
#
# 5. there seems to be a vulnerability in the notifications functionality.
#
# 6. we need details about your data encryption and compliance.
#
# 7. there seems to be a vulnerability in the mobile app functionality.
#
# 8. there seems to be a vulnerability in the billing functionality.
#
# 9. there seems to be a vulnerability in the data export functionality.

# %%
import pandas as pd
import re

# %%
DATA_FOLDER = ("../data/generated")

# %%
files = {
    "account_cleaned_final.txt": "account_access",
    "bp_cleaned.txt": "billing_problem",
    "bug_cleaned.txt": "bug",
    "feature_cleaned.txt": "feature_request",
    "how_to_cleaned.txt": "how_to",
    "other_cleaned.txt": "other",
    "performance_cleaned.txt": "performance",
    "security_cleaned.txt": "security_concern",
}

# %%
rows = []

for filename, label in files.items():

    filepath = os.path.join(DATA_FOLDER,filename)

    with open(filepath, "r", encoding="utf-8") as f:

        for line in f:

            line = line.strip()

            if not line:
                continue

            # Remove numbering like:
            # 1.
            # 24.
            # 103.

            if ". " in line:
                first, rest = line.split(". ", 1)

                if first.isdigit():
                    line = rest

            rows.append({
                "text": line,
                "label": label
            })

df = pd.DataFrame(rows)

# %%
print(df.shape)

print()

print(df.head())
# Out:
# (1316, 2)
#
#                                                 text           label
# 0  My grandson set this up for me but now I can't...  account_access
# 1  I just bought this service and it is asking fo...  account_access
# 2  I need to get into my daughter's account to ch...  account_access
# 3  I lost my student ID card and now I cannot log...  account_access
# 4  The little box where I am supposed to type my ...  account_access

# %%
print(df["label"].value_counts())
# Out:
# label
# account_access      206
# billing_problem     200
# performance         153
# security_concern    153
# bug                 152
# feature_request     151
# how_to              151
# other               150
# Name: count, dtype: int64

# %%
print("Before:", len(df))

df = df.drop_duplicates(subset="text")

print("After :", len(df))
# Out:
# Before: 1316
# After : 1316

# %%
df = df.sample(
    frac=1,
    random_state=42
).reset_index(drop=True)

# %%
OUTPUT_PATH = "../data/processed/issue_classification.csv"

df.to_csv(
    OUTPUT_PATH,
    index=False
)

print("Dataset saved successfully!")

print(df.shape)
# Out:
# Dataset saved successfully!
# (1316, 2)

# %%
import os
print(os.getenv("ANTHROPIC_API_KEY"))
# Out:
# None
