# %%
import pandas as pd

df = pd.read_csv(r"D:\AI-Customer-Support-Intelligence-Platform\data\raw\synthetic_it_support_tickets.csv")

print(df.shape)
df.head()
# Out:
# (100000, 20)
#      ticket_id           created_at customer_id customer_segment  \
# 0  TCKT_000001  2024-01-31T05:14:27  CUST_00861       individual
# 1  TCKT_000002  2024-10-20T06:15:49  CUST_00770       individual
# 2  TCKT_000003  2024-06-18T21:35:54  CUST_02559   small_business
# 3  TCKT_000004  2025-12-25T15:59:52  CUST_03557        education
# 4  TCKT_000005  2023-08-27T16:08:33  CUST_09556       enterprise
#
#             channel         product_area        issue_type priority  \
# 0             email          data_export    account_access      low
# 1            in_app              billing  security_concern   medium
# 2              chat      api_integration               bug      low
# 3              chat  analytics_dashboard    account_access   medium
# 4  phone_transcript           login_auth   billing_problem      low
#
#              status  sla_plan  \
# 0          resolved  standard
# 1  closed_no_action  standard
# 2       in_progress  standard
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ticket_id              100000 non-null  str
#  1   created_at             100000 non-null  str
#  2   customer_id            100000 non-null  str
#  3   customer_segment       100000 non-null  str
#  4   channel                100000 non-null  str
#  5   product_area           100000 non-null  str
#  6   issue_type             100000 non-null  str
#  7   priority               100000 non-null  str
#  8   status                 100000 non-null  str
#  9   sla_plan               100000 non-null  str
#  10  initial_message        100000 non-null  str
#  11  agent_first_reply      100000 non-null  str
#  12  resolution_summary     60113 non-null   str
#  13  resolution_time_hours  60113 non-null   float64
#  14  reopened               100000 non-null  int64
# ...

# %%
print(df.columns.tolist())
# Out:
# ['ticket_id', 'created_at', 'customer_id', 'customer_segment', 'channel', 'product_area', 'issue_type', 'priority', 'status', 'sla_plan', 'initial_message', 'agent_first_reply', 'resolution_summary', 'resolution_time_hours', 'reopened', 'customer_sentiment', 'csat_score', 'has_attachment', 'platform', 'region']

# %%
df.sample(10, random_state=42)
# Out:
#          ticket_id           created_at customer_id customer_segment  \
# 75721  TCKT_075722  2024-02-02T23:07:49  CUST_03968       non_profit
# 80184  TCKT_080185  2025-11-16T19:07:23  CUST_05746       individual
# 19864  TCKT_019865  2025-12-02T22:15:37  CUST_04592   small_business
# 76699  TCKT_076700  2024-06-22T04:06:43  CUST_04204       individual
# 92991  TCKT_092992  2024-08-16T03:33:46  CUST_03044       enterprise
# 76434  TCKT_076435  2025-11-15T17:45:27  CUST_06456        education
# 84004  TCKT_084005  2023-09-11T01:47:28  CUST_08153        education
# 80917  TCKT_080918  2023-04-16T17:21:33  CUST_00534       non_profit
# 60767  TCKT_060768  2023-11-17T04:53:26  CUST_02880       enterprise
# 50074  TCKT_050075  2024-12-28T06:45:17  CUST_09710   small_business
#
#                 channel     product_area       issue_type priority  \
# 75721  phone_transcript    notifications            other     high
# 80184            in_app       login_auth   account_access   urgent
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# resolution_summary       39887
# resolution_time_hours    39887
# region                   19997
# ticket_id                    0
# customer_segment             0
# customer_id                  0
# created_at                   0
# channel                      0
# status                       0
# product_area                 0
# issue_type                   0
# priority                     0
# agent_first_reply            0
# initial_message              0
# sla_plan                     0
# reopened                     0
# customer_sentiment           0
# csat_score                   0
# has_attachment               0
# platform                     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# ticket_id                    0
# created_at                   0
# customer_id                  0
# customer_segment             0
# channel                      0
# product_area                 0
# issue_type                   0
# priority                     0
# status                       0
# sla_plan                     0
# initial_message              0
# agent_first_reply            0
# resolution_summary       39887
# resolution_time_hours    39887
# reopened                     0
# customer_sentiment           0
# csat_score                   0
# has_attachment               0
# platform                     0
# region                   19997
# dtype: int64

# %%
df["resolution_time_hours"].describe()
# Out:
# count    60113.000000
# mean        45.013123
# std         49.202797
# min          0.110000
# 25%         14.880000
# 50%         29.910000
# 75%         51.660000
# max        239.960000
# Name: resolution_time_hours, dtype: float64

# %%
for text in df["initial_message"].sample(5, random_state=42):
    print("="*80)
    print(text)
# Out:
# ...
# I need help but I'm not sure which category this fits in.
# ...
# My account was locked after multiple failed login attempts.
# ...
# I cannot log in; the system says my password is incorrect.
# ...
# I am seeing an error message when I click on data export.
# ...
# My 2FA code is not working when I try to sign in.
