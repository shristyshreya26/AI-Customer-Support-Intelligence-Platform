# %%
import pandas as pd

df = pd.read_csv("D:/AI-Customer-Support-Intelligence-Platform/data/processed/clean_customer_support_dataset_with_derived_sentiment.csv")

print(df.columns.tolist())
# Out:
# ['ticket_id', 'created_at', 'customer_id', 'customer_segment', 'channel', 'product_area', 'issue_type', 'priority', 'status', 'sla_plan', 'initial_message', 'agent_first_reply', 'resolution_summary', 'resolution_time_hours', 'reopened', 'customer_sentiment', 'csat_score', 'has_attachment', 'platform', 'region', 'message_length', 'word_count', 'is_resolved', 'predicted_emotion', 'customer_sentiment_derived']
